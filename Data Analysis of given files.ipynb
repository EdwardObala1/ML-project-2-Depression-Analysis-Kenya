# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

datafile=pd.read_csv("AI-Lab-master/train.csv")
datafile
# Out:
#       surveyid  village survey_date  femaleres   age  married  children  \
# 0          926       91   23-Nov-61          1  28.0        1         4
# 1          747       57   24-Oct-61          1  23.0        1         3
# 2         1190      115   05-Oct-61          1  22.0        1         3
# 3         1065       97   23-Sep-61          1  27.0        1         2
# 4          806       42   12-Sep-61          0  59.0        0         4
# ...        ...      ...         ...        ...   ...      ...       ...
# 1138       927      152   27-Dec-61          1  36.0        0         4
# 1139      1039      104   13-Sep-61          1  23.0        1         0
# 1140       428       54   23-Nov-61          1  28.0        1         5
# 1141        23        3   05-Oct-61          1  33.0        0         4
# 1142       116       18   24-Sep-61          1  39.0        1         0
#
#       hhsize  edu  hh_children  ...  given_mpesa  amount_given_mpesa  \
# ...

# %%
women=(list(datafile.femaleres).count(1))
men=(list(datafile.femaleres).count(0))

print(women)
print(men)

df = pd.DataFrame({'lab':['women', 'men',], 'val':[women,men]})
ax = df.plot.bar(x='lab', y='val', rot=0)
ax.legend()

fig = plt.gcf()
fig.set_size_inches(10.5, 5)
fig.savefig('men_women.png', dpi=100)
# Out:
# 1048
# 95

# %%
married=(list(datafile.married).count(1))
single=(list(datafile.married).count(0))

print(married)
print(single)

df = pd.DataFrame({'lab':['married', 'single/other relationship',], 'val':[married,single]})
ax = df.plot.bar(x='lab', y='val', rot=0)
ax.legend()

fig = plt.gcf()
fig.set_size_inches(10.5, 5)
fig.savefig('married_single.png', dpi=100)
# Out:
# 883
# 260
